# %% [markdown]
# # Applications mathématiques de python
#
# **Olivier Chabot**, 2022

# %%
# Importer des packages pour les maths
import numpy as np
import matplotlib.pyplot as plt

# %%
my_vector = np.array([1, 2 ,3 ,4])
np.sqrt(my_vector)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        ])

# %% [markdown]
# ## Graphique des fonctions

# %%
# Polynôme de degré 1
x = np.linspace(0, 10)
a = 3
b = 2
y = a*x + b
plt.plot(x,y)

# %%
# Polynôme de degré 2
# Forme générale

x = np.linspace(-5, 5)
a = 1
b = -2
c = 2
y = a*x**2 + b*x + c
plt.plot(x,y, label=str(n))

# %%
# Polynôme de degré 2
# Forme canonique
x = np.linspace(-5, 5)
a = -0.5
h = 1
k = 5
y = a*(x - h)**2 + k
plt.plot(x,y)
plt.grid('on')

# %%
# Polynôme de degré 2
# Forme factorisée
x = np.linspace(-5, 5)
x_1 = -4
x_2 = 3
a = 1
y = a*(x - x_1)*(x - x_2)
plt.plot(x, y)
plt.scatter([x_1, x_2], [0, 0])
plt.annotate('({x}, 0)'.format(x=x_1), (x_1, 0))
plt.grid('on')

# %%
# Réciproque du polynome de degré 2
x = np.linspace(0, 15)
y = np.sqrt((x))

plt.plot(x, y)
plt.grid('on')

# %%
# Fonction exponentielle
x = np.linspace(0, 2)
a = 1
c = 10
b = 0.5
y = a*c**(b*x)
plt.plot(x, y)
plt.grid('on')

# %%
# Fonction escalier
x = np.linspace(0, 10, 200)
a = 2
h = 0
k = 3
y = a*np.floor(x - h) + k
plt.plot(x,y)

# %%
# Fonctions périodiques
x = np.linspace(-np.pi, np.pi)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# ## Résolution de systèmes d'équation

# %%
Y
# Out:
# array([[0.        , 0.        , 0.        , 0.        ],
#        [0.33333333, 0.33333333, 0.33333333, 0.33333333],
#        [0.66666667, 0.66666667, 0.66666667, 0.66666667],
#        [1.        , 1.        , 1.        , 1.        ]])

# %%
X > 0.6
# Out:
# array([[False, False,  True,  True],
#        [False, False,  True,  True],
#        [False, False,  True,  True],
#        [False, False,  True,  True]])

# %%
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)
plt.plot([0, 1, 1, 0, 0], [0, 0, 1, 1, 0], color='k')
    
plt.scatter(X[(Y > 0.6)], 
            Y[(Y > 0.6)], color='r')

# %%
# Méthode graphique
x = np.linspace(-5, 5)
# eq. 1 : 
y1 = 3*x + 1
# eq. 2 : 
y2 = -x**2 + 2*x + 3
# graphique
plt.plot(x, y1)
plt.plot(x, y2)
plt.grid('on')

# %% [markdown]
# ## Distance entre deux points (application)

# %%
help(plt.arrow)
# Out:
# Help on function arrow in module matplotlib.pyplot:
#
# arrow(x, y, dx, dy, **kwargs)
#     Add an arrow to the Axes.
#
#     This draws an arrow from ``(x, y)`` to ``(x+dx, y+dy)``.
#
#     Parameters
#     ----------
#     x, y : float
#         The x and y coordinates of the arrow base.
#
#     dx, dy : float
#         The length of the arrow along x and y direction.
#
#     width : float, default: 0.001
#         Width of full arrow tail.
#
#     length_includes_head : bool, default: False
#         True if head is to be counted in calculating the length.
#
#     head_width : float or None, default: 3*width
#         Total width of the full arrow head.
#
#     head_length : float or None, default: 1.5*head_width
#         Length of arrow head.
#
#     shape : {'full', 'left', 'right'}, default: 'full'
#         Draw the left-half, right-half, or full arrow.
#
#     overhang : float, default: 0
#         Fraction that the arrow is swept back (0 overhang means
# ...

# %%
def tracer_plan_cartesien():
    plt.arrow(-1, 0, 2, 0, width=0.005, head_width=0.05, color='k')
    plt.arrow(0, -1, 0, 2, width=0.005, head_width=0.05, color='k')
    plt.grid('on')

def tracer(x, y, **kwargs):
    tracer_plan_cartesien()
    plt.plot(x, y, **kwargs)
    plt.legend()

# %%
from aide_a_leducation import *

# %%
x = np.linspace(-1, 1)
a1 = 0.25
b1 = 0
y1 = a1*x + b1
tracer(x, y, label='b=0')
b = 0.2
y = -a*x + b
tracer(x, y, label='b=0.2')

# %%
b = 0
tracer_droite(a=0.25, b=0)
tracer_droite(a=0.5, b=0)
tracer_droite(a=1., b=0)
    
tracer_plan_cartesien()
plt.legend()

# %%
x_values = np.random.random(15)
y_values = np.random.random(15)
points = np.vstack([x_values, y_values]).T
fig, ax = plt.subplots()

def distance(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

d_points = 0
p1 = 0
p2 = 0
for i, pi in enumerate(points):
    for j, pj in enumerate(points):
        d = distance(pi, pj)
        if d > d_points:
            d_points = d
            p1 = pi
            p2 = pj
            
plt.scatter(*points.T, color='0.4')
plt.scatter(*p1, color='b')
plt.scatter(*p2, color='b')
plt.plot([p1[0], p2[0]], [p1[1],p2[1]], color='b')
ax.set_aspect('equal')

# %%
x = np.array()
